# %% [markdown]
# ## Downloading a dataset from Roboflow and training a model

# %% [markdown]
# There are two options:
#
# 1. Find a dataset on Roboflow which interests you, and download it in YOLOv8 format
# 2. Upload your own images into Roboflow, annotate them, and download your dataset in YOLOv8 format

# %%
# install the necessary packages

# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
# WARNING: Ignoring invalid distribution -atplotlib (d:\hirac\notebooks\hirac_venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\hirac\notebooks\hirac_venv\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: D:\hirac\notebooks\hirac_venv\scripts\python.exe -m pip install --upgrade pip
# ...
# WARNING: Ignoring invalid distribution -atplotlib (d:\hirac\notebooks\hirac_venv\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (d:\hirac\notebooks\hirac_venv\lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 24.0
# [notice] To update, run: D:\hirac\notebooks\hirac_venv\scripts\python.exe -m pip install --upgrade pip

# %%
# import the packages we use

from ultralytics import YOLO
from roboflow import Roboflow
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# if using a GPU:
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA RTX A2000 Laptop GPU

# %% [markdown]
# The following code allows you to download the dataset and is given to you by roboflow:

# %%
rf = Roboflow(api_key="insertAPI")
project = rf.workspace("hochschule-offenburg").project("assistive-objects-daily-tasks-xsaxj")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.194, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Assistive-Objects-Daily-Tasks-1 in yolov8:: 100%|██████████| 5818/5818 [00:04<00:00, 1289.71it/s]

# %%
# the model will download into the folder if it does not yet exist
# add the dataset directory in "C:\Users\kponomar\AppData\Roaming\Ultralytics\settings.yaml"

model = YOLO('yolov8n.pt')

# %%
results = model.train(data="Assistive-Objects-Daily-Tasks-1/data.yaml", epochs=10, device=0)
# Out:
# New https://pypi.org/project/ultralytics/8.2.23 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.194  Python-3.9.0 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A2000 Laptop GPU, 4096MiB)
# ...

# %%
# cup
model.predict('D:/Assistive_Dataset/assistive_objects_dataset/test/images/000000321008_jpg.rf.dafeab81c541e94aaeb3f919ebfe4296.jpg', save=True)

#fork
model.predict('D:/Assistive_Dataset/assistive_objects_dataset/train/images/000000268317_jpg.rf.f12ccdcce5be3636af0a691e172ae770.jpg', save=True)

#scissors
model.predict('D:/Assistive_Dataset/assistive_objects_dataset/valid/images/000000463226_jpg.rf.8fa75335d02d9a87584df74defff794a.jpg', save=True)

#spoon
model.predict('D:/Assistive_Dataset/assistive_objects_dataset/train/images/000000037109_jpg.rf.226da8bf51fea066f63eb0425c4c8177.jpg', save=True)
# Out:
# image 1/1 D:\Assistive_Dataset\assistive_objects_dataset\test\images\000000321008_jpg.rf.dafeab81c541e94aaeb3f919ebfe4296.jpg: 640x640 1 cup, 1 fork, 115.5ms
# Speed: 14.0ms preprocess, 115.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict27
#
# image 1/1 D:\Assistive_Dataset\assistive_objects_dataset\train\images\000000268317_jpg.rf.f12ccdcce5be3636af0a691e172ae770.jpg: 640x640 1 fork, 114.9ms
# Speed: 0.0ms preprocess, 114.9ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict28
#
# image 1/1 D:\Assistive_Dataset\assistive_objects_dataset\valid\images\000000463226_jpg.rf.8fa75335d02d9a87584df74defff794a.jpg: 640x640 1 scissors, 6.0ms
# Speed: 14.2ms preprocess, 6.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict29
#
# ...

# %%
# Load your three images from local files (replace with your file paths)
image1 = mpimg.imread('D:/Assistive_Dataset/runs/detect/predict27/000000321008_jpg.rf.dafeab81c541e94aaeb3f919ebfe4296.jpg')
image2 = mpimg.imread('D:/Assistive_Dataset/runs/detect/predict28/000000268317_jpg.rf.f12ccdcce5be3636af0a691e172ae770.jpg')
image3 = mpimg.imread('D:/Assistive_Dataset/runs/detect/predict29/000000463226_jpg.rf.8fa75335d02d9a87584df74defff794a.jpg')
image4 = mpimg.imread('D:/Assistive_Dataset/runs/detect/predict30/000000037109_jpg.rf.226da8bf51fea066f63eb0425c4c8177.jpg')

import matplotlib.pyplot as plt


# Create a grid of 4 rows and 3 columns
num_rows = 2
num_cols = 2
fig, axes = plt.subplots(num_rows, num_cols, figsize=(10, 10), constrained_layout=True)

# Iterate over each row and column to display the images
for i in range(num_rows):
    for j in range(num_cols):
        image_index = i * num_cols + j + 1  # Calculate the index of the image
        if image_index <= 12:  # Check if image_index is within range
            img = locals()[f'image{image_index}']  # Get the image variable dynamically
            axes[i, j].imshow(img)
            axes[i, j].axis('off')
            #axes[i, j].set_title(f'Image {image_index}')
        else:
            axes[i, j].axis('off')
            axes[i, j].text(0.5, 0.5, 'No Image', 
                            horizontalalignment='center', verticalalignment='center', 
                            transform=axes[i, j].transAxes)

#plt.tight_layout()
plt.suptitle('YOLOv5n pretrained on COCO, predictions on cutlery and cups')
plt.show()
